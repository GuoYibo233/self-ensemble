# %%
from datasets import load_dataset

train_ds = load_dataset("stanfordnlp/web_questions", split="train")
test_ds = load_dataset("stanfordnlp/web_questions", split="test")
train_ds = train_ds.filter(lambda x: len(x["answers"]) == 1)
test_ds = test_ds.filter(lambda x: len(x["answers"]) == 1)
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: pyarrow.lib.ChunkedArray size changed, may indicate binary incompatibility. Expected 64 from C header, got 72 from PyObject
# <frozen importlib._bootstrap>:241: RuntimeWarning: pyarrow.lib._Tabular size changed, may indicate binary incompatibility. Expected 24 from C header, got 32 from PyObject
# <frozen importlib._bootstrap>:241: RuntimeWarning: pyarrow.lib.Table size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
for q, a in zip(test_ds["question"], test_ds["answers"]):
    print(f"Q: {q}\nA: {a[0]}\n")
# Out:
# Q: what did james k polk do before he was president?
# A: Lawyer
#
# Q: what is the oregon ducks 2012 football schedule?
# A: University of Oregon
#
# Q: who plays ken barlow in coronation street?
# A: Tony Warren
#
# Q: what happened after mr. sugihara died?
# A: Yaotsu
#
# Q: who did mozart write his four horn concertos for?
# A: wolfgang amadeus mozart used story by pierre beaumarchais
#
# Q: where is jamarcus russell from?
# A: Mobile
#
# Q: where was george washington carver from?
# A: Diamond
#
# Q: who was richard nixon married to?
# A: Pat Nixon
#
# Q: what country did germany invade first in ww1?
# A: Belgium
#
# Q: who is governor of ohio 2011?
# A: John Kasich
#
# Q: who was vice president after kennedy died?
# A: Lyndon B. Johnson
#
# Q: who is the minority leader of the house of representatives now?
# A: Nancy Pelosi
#
# Q: who is keyshia cole dad?
# A: Leon Cole
#
# Q: what town was martin luther king assassinated in?
# A: Memphis
#
# Q: where did edgar allan poe died?
# A: Baltimore
#
# Q: when did charles goodyear invented rubber?
# A: During the early 1830's he began inventing, filing six patents between 1830 and 1834, and during this period became interested in rubber, which he tried - unsuccessfully - to use in some of his mechanical inventions.
#
# Q: who did france surrender to in ww2?
# A: Germany
#
# Q: what electorate does anna bligh represent?
# A: Electoral district of South Brisbane
#
# Q: what channel is the usa pageant on?
# A: us
#
# Q: where did andy murray started playing tennis?
# A: United Kingdom
#
# Q: what is the australian dollar called?
# A: Australian dollar
#
# Q: what timezone is sweden?
# A: Central European Time
#
# Q: who did cam newton sign with?
# A: Carolina Panthers
#
# Q: what county is frederick md in?
# A: Frederick County
#
# Q: what highschool did harper lee go to?
# A: Monroe County High School
#
# Q: what timezone is utah in?
# A: Mountain Time Zone
#
# Q: who did george w. bush run against for the second term?
# A: Al Gore
#
# Q: who is niall ferguson's wife?
# A: Ayaan Hirsi Ali
#
# Q: who was the leader of soviet union during wwii?
# A: Joseph Stalin
#
# Q: what is the state flower of arizona?
# A: Saguaro
#
# Q: what year did president william henry harrison take office?
# A: 3/4/1841
#
# Q: where george lopez was born?
# A: Mission Hills
#
# Q: where are samsung based?
# A: Seoul
#
# Q: what did the scientist chadwick discovered?
# A: Neutron
#
# Q: who will play mr gray in the film?
# A: Karen Mulder
#
# Q: what did george orwell died of?
# A: Tuberculosis
#
# Q: who won the battle of gettysburg union or confederate?
# A: Union
#
# Q: what country did adolf hitler control?
# A: Germany
#
# Q: what county is kansas city kansas?
# A: Wyandotte County
#
# Q: when did annie open?
# A: Annie (1977 original Broadway cast)
#
# Q: where did eleanor roosevelt die?
# A: New York City
#
# Q: who was the first dictator of the soviet union?
# A: Joseph Stalin
#
# Q: what is the currency of puerto rico called?
# A: United States dollar
#
# Q: what kind of cancer did carl wilson have?
# A: Lung cancer
#
# Q: who plays the voice of kitt in knight rider?
# A: William Daniels
#
# Q: what county is brentwood tennessee in?
# A: Williamson County
#
# Q: who is moira en x men?
# A: Mutant
#
# Q: who did michael j fox marry?
# A: Tracy Pollan
#
# Q: what language do the maasai tribe speak?
# A: Maasai Language
#
# Q: who did benjamin franklin get married to?
# A: Deborah Read
#
# Q: what disease did patrick swayze died from?
# A: Pancreatic cancer
#
# Q: what capital of austria?
# A: Vienna
#
# Q: what type of cancer did eva peron have?
# A: Cervical cancer
#
# Q: what country did buddha come from?
# A: India
#
# Q: what county is greeley colorado in?
# A: Weld County
#
# Q: where is the ellen degenerous show filmed?
# A: Beverly Hills
#
# Q: what did peter tchaikovsky do?
# A: Composer
#
# Q: which country does greenland belong to?
# A: Denmark
#
# Q: who is willow smith mom name?
# A: Jada Pinkett Smith
#
# Q: what do you call the chinese writing system?
# A: Standard Mandarin
#
# Q: what made the soviet union fall?
# A: Cold War
#
# Q: what continent does armenia belong to?
# A: Eurasia
#
# Q: where did richard nixon die?
# A: New York City
#
# Q: who was vice president when jfk was president?
# A: Lyndon B. Johnson
#
# Q: what is serbian language called?
# A: Serbian language
#
# Q: what are the names of the city states in ancient greece?
# A: Athens
#
# Q: who played barbara gordon batgirl?
# A: Alicia Silverstone
#
# Q: where is jay leno from?
# A: New Rochelle
#
# Q: who did armie hammer play in the social network?
# A: Jesse Eisenberg
#
# Q: what was thomas jefferson role in the declaration of independence?
# A: Writer
#
# Q: who did tim tebow play college football for?
# A: University of Florida
#
# Q: who does peyton manning play football for?
# A: Denver Broncos
#
# Q: what did anton van leeuwenhoek contribute to our knowledge of cells?
# A: microscope first used by anton van leeuwenhoek
#
# Q: who did the voice of darth vader in episode 3?
# A: Hayden Christensen
#
# Q: what super bowl did peyton manning win?
# A: 2006 NFL season
#
# Q: which country was justin bieber born in?
# A: Canada
#
# Q: where are yamaha outboard motors manufactured?
# A: Shizuoka Prefecture
#
# Q: who plays london tipton in suite life on deck?
# A: Brenda Song
#
# Q: what was the ancient chinese writing system?
# A: Sino-Tibetan languages
#
# Q: what team did david beckham play for in 2011?
# A: LA Galaxy
#
# Q: where did francisco coronado come from?
# A: Salamanca
#
# Q: what language does egyptian people speak?
# A: Modern Standard Arabic
#
# Q: what type of cancer did gilda radner die of?
# A: Ovarian cancer
#
# Q: who plays juni cortez?
# A: Daryl Sabara
#
# Q: who did carrie ann inaba get engaged to?
# A: Jesse Sloan
#
# Q: who is michael j fox wife?
# A: Tracy Pollan
#
# Q: where did dolly parton grow up?
# A: Tennessee
#
# Q: what type of books did agatha christie wrote?
# A: Crime writer
#
# Q: who is the woman that john edwards had an affair with?
# A: Rielle Hunter
#
# Q: what is jimi hendrix purple haze about?
# A: Drug overdose
#
# Q: where can i go running in sacramento?
# A: Boulevard Park
#
# Q: where is the nra headquarters located?
# A: Fairfax
#
# Q: what is the song anna kendrick sings in pitch perfect?
# A: Cups
#
# Q: who is gimli's father in the hobbit?
# A: Gloin
#
# Q: who led the campaign in the shenandoah valley?
# A: Jackson's Valley Campaign
#
# Q: who founded the pittsburgh steelers in 1933?
# A: Rooney family
#
# Q: what team does jordan own?
# A: Jordan national football team
#
# Q: who is the state governor of tennessee?
# A: Bill Haslam
#
# Q: who is eli whitney and what did he invent?
# A: Cotton gin
#
# Q: what do portuguese people speak?
# A: Portuguese
#
# Q: what language does cuba speak?
# A: Spanish Language
#
# Q: where did aaron rodgers go to high school?
# A: Pleasant Valley High School
#
# Q: where herman cain stance on the issues?
# A: Évocateur: The Morton Downey Jr. Movie
#
# Q: what year was george w bush elected?
# A: George W. Bush presidential campaign, 2000
#
# Q: where is mission san buenaventura located?
# A: Ventura County
#
# Q: who was the italian leader in ww1?
# A: Benito Mussolini
#
# Q: what time in hilo hawaii?
# A: Hawaii–Aleutian Time Zone
#
# Q: what university did gordon brown attend?
# A: University of Edinburgh
#
# Q: what year did the seahawks win the superbowl?
# A: 2006 NFL season
#
# Q: who plays donna noble?
# A: Catherine Tate
#
# Q: where did queensland get its name from?
# A: Queen Victoria
#
# Q: what do you call members of the senate?
# A: Senator
#
# Q: what team does colin kaepernick play for?
# A: San Francisco 49ers
#
# Q: where did joe flacco attend college?
# A: University of Delaware
#
# Q: who is emma stone father?
# A: Jeff Stone
#
# Q: where was theodore roosevelt buried?
# A: Youngs Memorial Cemetery
#
# Q: who was the leader of the us during wwii?
# A: Gerald Ford
#
# Q: where the missouri river ends?
# A: Mississippi River
#
# Q: what type of currency do they use in thailand?
# A: Thai baht
#
# Q: who is khloe kardashian's husband?
# A: Lamar Odom
#
# Q: what years did romney serve as governor?
# A: 1/2/2003
#
# Q: what state does romney live in?
# A: Massachusetts
#
# Q: who rules denmark right now?
# A: Helle Thorning-Schmidt
#
# Q: what did stephen hawking study?
# A: Physics
#
# Q: what region of the world is egypt associated with?
# A: Middle East
#
# Q: what did dr. seuss do?
# A: Writer
#
# Q: where did drew brees go to college wikianswers?
# A: Purdue University
#
# Q: what are republicans views on health care?
# A: 20003
#
# Q: what school did ben roethlisberger go to?
# A: Miami University
#
# Q: where did the iroquois indians come from?
# A: Québec
#
# Q: what places make up new england?
# A: Maine
#
# Q: who did gerald ford select as his vice president when he became president?
# A: Nelson Rockefeller
#
# Q: what is the currency used in italy?
# A: Euro
#
# Q: who is jamie little engaged to?
# A: Cody Selman
#
# Q: what is the capital of modern egypt?
# A: Cairo
#
# Q: where is harvard university?
# A: Massachusetts
#
# Q: what does janelle brown work?
# A: Actor
#
# Q: where is laos in world map?
# A: Cambodia
#
# Q: where is tyrese gibson from?
# A: Watts
#
# Q: where was elvis costello born?
# A: Paddington
#
# Q: where are the gobi desert located on a map?
# A: Mongolia
#
# Q: in which continent is germany?
# A: Europe
#
# Q: when did the wright brothers created their first plane?
# A: 1900 Wright Glider
#
# Q: what language turkey people speak?
# A: Turkish Language
#
# Q: who does jeremy lin play for?
# A: Houston Rockets
#
# Q: where is the seychelles on world map?
# A: Africa
#
# Q: what is the average temperature in phoenix az in december?
# A: Phoenix should not be contained in Maricopa County.
#
# Q: what state is mount st. helens in?
# A: Washington
#
# Q: who is jimmy savile?
# A: Presenter
#
# Q: where were the seneca indians located?
# A: New York
#
# Q: what is william taft known for?
# A: President of the United States
#
# Q: where to exchange euros in new york city?
# A: John F. Kennedy International Airport
#
# Q: when did florida marlins join mlb?
# A: 1993 Major League Baseball Season
#
# Q: what countries have spanish as the national language?
# A: Spain
#
# Q: what countries does the panama canal go through?
# A: Panama Canal Zone
#
# Q: what is charlie chaplin famous for?
# A: Comedian
#
# Q: who did paul revere marry?
# A: Sarah Revere
#
# Q: what did fred durst do?
# A: Musician
#
# Q: who did the chargers draft in 2011?
# A: Frank Summers
#
# Q: where do american bulldogs originate from?
# A: United States of America
#
# Q: who plays the voice of brian on family guy?
# A: Seth MacFarlane
#
# Q: what make of bike did steve mcqueen ride in the great escape?
# A: Yucatan
#
# Q: where did george w bush live as a child?
# A: New Haven
#
# Q: which dawkins book to read first?
# A: The Selfish Gene
#
# Q: what year was the first miss america pageant held?
# A: 1930 Miss America
#
# Q: what was nikola tesla inventions?
# A: Tesla coil
#
# Q: where did flemish people come from?
# A: Belgium
#
# Q: what state new york city belong to?
# A: New York
#
# Q: what was the cause of death for bruce lee?
# A: Cerebral edema
#
# Q: what type of government does usa follow?
# A: Federal republic
#
# Q: what type of currency do they use in england?
# A: UK £
#
# Q: where was benjamin franklin educated?
# A: Boston Latin School
#
# Q: what is the primary language of china?
# A: Standard Mandarin
#
# Q: who was the soviet leader during world war ii?
# A: Alexei Negmatov
#
# Q: where was david berkowitz arrested?
# A: New York City
#
# Q: where was the city of david?
# A: Bethlehem
#
# Q: what is cindy sherman known for?
# A: Photographer
#
# Q: what does australia use for currency?
# A: Australian dollar
#
# Q: where was martin luther king jr raised?
# A: Atlanta
#
# Q: what year was lebron james rookie season?
# A: 2003–04 NBA season
#
# Q: what kind of monarchy does japan have?
# A: Constitutional monarchy
#
# Q: where did mitt romney's parents come from?
# A: Bloomfield Hills
#
# Q: what places in japan were bombed?
# A: Hiroshima Prefecture
#
# Q: when did michael jordan return to the nba?
# A: 2001–02 NBA season
#
# Q: what type of economy exists in china?
# A: Socialist state
#
# Q: what is the currency in egypt 2012?
# A: Egyptian pound
#
# Q: where was mission san rafael located?
# A: California
#
# Q: who was esther's husband?
# A: Susa
#
# Q: who's dating claire danes?
# A: Hugh Dancy
#
# Q: what produce does florida export?
# A: Orange juice
#
# Q: what did drita find out?
# A: Football Superleague of Kosovo
#
# Q: when does the mayan calendar end exactly?
# A: 2012
#
# Q: when does jewish new year start?
# A: Yiddish Language
#
# Q: when do world war ii end?
# A: 1942
#
# Q: who did queen elizabeth 1 executed?
# A: queen elizabeth i of england she executed mary queen of scots
#
# Q: where is arabic most spoken?
# A: Saudi Arabia
#
# Q: who was carolus linnaeus?
# A: Botanist
#
# Q: what time zone is anaheim california?
# A: Pacific Time Zone
#
# Q: what would ap xin zhao do?
# A: Male
#
# Q: who is sir francis bacon?
# A: Philosopher
#
# Q: where did margaret hoover go to college?
# A: Davidson College
#
# Q: where does bradley walsh live?
# A: England
#
# Q: who is the head coach of inter milan?
# A: Andrea Stramaccioni
#
# Q: where does the shannon river start and end?
# A: Shannon Pot
#
# Q: who did reese witherspoon get married to?
# A: Ryan Phillippe
#
# Q: where did dutch language come from?
# A: Europeans
#
# Q: what kind of money should i take to costa rica?
# A: Costa Rican colón
#
# Q: where is the ufc headquarters?
# A: Las Vegas
#
# Q: who plays captain kirk in star trek?
# A: William Shatner
#
# Q: who does albert pujols play for 2012?
# A: Los Angeles Angels of Anaheim
#
# Q: where was country singer george jones born?
# A: Saratoga
#
# Q: where does russia import from?
# A: Uzbekistan
#
# Q: what is the money of switzerland called?
# A: Swiss franc
#
# Q: when did the jews stop making animal sacrifices?
# A: Yiddish Language
#
# Q: what movies did ron howard director?
# A: How the Grinch Stole Christmas!
#
# Q: what role did alexander hamilton play in the constitution?
# A: Financier
#
# Q: who is shakira married to?
# A: Gerard Piqué
#
# Q: what did gerald r ford die from?
# A: Cardiovascular disease
#
# Q: where did kevin love go to college?
# A: University of California, Los Angeles
#
# Q: what type of government was formed when italy unified?
# A: Parliamentary republic
#
# Q: what was the ancient egyptians spoken language?
# A: Egyptian Arabic
#
# Q: who is the senior senator of louisiana?
# A: Mary Landrieu
#
# Q: who did john kennedy have affairs with?
# A: william averell harriman appointed by john fitzgerald kennedy
#
# Q: what type of money to take to cuba?
# A: Cuban peso
#
# Q: what currency should you take to morocco?
# A: Moroccan dirham
#
# Q: who is mary mcleod bethune for kids?
# A: Educator
#
# Q: what do they call money in japan?
# A: Japanese yen
#
# Q: what nationality is mother teresa?
# A: India
#
# Q: what county is west st paul in?
# A: Dakota County
#
# Q: what college did magic johnson play for?
# A: Michigan State University
#
# Q: who does donnie wahlberg play in the sixth sense?
# A: Vincent Grey
#
# Q: what did baron de montesquie influence?
# A: charles-louis de secondat montesquieu influenced edward gibbon
#
# Q: what do australians call bigfoot?
# A: Waleed Aly
#
# Q: who owns the portland press herald?
# A: Blethen Maine Newspapers, Inc.
#
# Q: who does jordan palmer play for?
# A: Jacksonville Jaguars
#
# Q: what art movement did leonardo da vinci belong to?
# A: High Renaissance
#
# Q: what time does american horror story air?
# A: Tom Selleck
#
# Q: what airport is near arlington tx?
# A: Arlington Municipal Airport
#
# Q: who did vasco de gama explore for?
# A: Portugal
#
# Q: what team does heskey play for?
# A: Newcastle Jets FC
#
# Q: where did emperor hirohito live?
# A: Japan
#
# Q: when did conflict start in ireland?
# A: Viking invasion of Ireland
#
# Q: when did the lakers 3 peat?
# A: 2000
#
# Q: what makes elvis presley famous?
# A: Singer
#
# Q: what high school did lil wayne graduate from?
# A: Mcmain Magnet Secondary School
#
# Q: who is washington redskins backup qb?
# A: Rex Grossman
#
# Q: what to do in richardson dallas?
# A: Wizard's Sports Cafe
#
# Q: what was the first book charles dickens wrote?
# A: Oliver Twist
#
# Q: which continental congress approve the declaration of independence?
# A: Second Continental Congress
#
# Q: what year does hitler die?
# A: Hitler and His Generals: Military Conferences 1942-1945
#
# Q: where is mount st helens volcano?
# A: Skamania County
#
# Q: what book did tupac write?
# A: The Rose That Grew from Concrete
#
# Q: what was robert burns famous for?
# A: Poet
#
# Q: when did william mckinley died?
# A: 9/14/1901
#
# Q: how deep is lake merritt oakland?
# A: Oakland
#
# Q: who is the next governor of indiana?
# A: Mitch Daniels
#
# Q: when was the last time the toronto maple leafs were in the stanley cup finals?
# A: 1967 Stanley Cup Finals
#
# Q: what currency does russia use 2012?
# A: Russian ruble
#
# Q: what team is hank baskett on 2010?
# A: Philadelphia Eagles
#
# Q: who is hammurabi and what did he do?
# A: Monarch
#
# Q: what state is the steelers from?
# A: Pittsburgh
#
# Q: what are the school colors for harvard university?
# A: Crimson
#
# Q: what disease does robin roberts have?
# A: Breast cancer
#
# Q: what was the capital city of the east roman empire?
# A: Constantinople
#
# Q: who plays edward scissorhands?
# A: Johnny Depp
#
# Q: what does joey jordison play in slipknot?
# A: Drums
#
# Q: what kind of language does turkey speak?
# A: Turkish Language
#
# Q: what was lebron james first team?
# A: Cleveland Cavaliers
#
# Q: who is the coach of the sf giants?
# A: Tim Flannery
#
# Q: where can you go on eco holidays in the uk?
# A: World Bank, World Development Indicators, Life Expectancy
#
# Q: where did giuliana rancic grow up?
# A: Naples
#
# Q: what are the major cities in ukraine?
# A: Kiev
#
# Q: what did queen victoria say about the suffragettes?
# A: I am every day more convinced that we women, if we are to be good women, feminine and amiable and domestic, are not fitted to reign; at least it is they that drive themselves to the work which it entails.
#
# Q: what is st anthony patron saint of?
# A: Padua
#
# Q: who does brian dawkins play for 2011?
# A: Denver Broncos
#
# Q: what movies did tupac star in?
# A: Nothing but Trouble
#
# Q: what form of currency does china have?
# A: Renminbi
#
# Q: who plays kenneth?
# A: Jack McBrayer
#
# Q: what league are the indianapolis colts in?
# A: AFC South
#
# Q: what country did magellan represent?
# A: Portugal
#
# Q: where is perpignan located?
# A: France
#
# Q: when's the last time the steelers won the superbowl?
# A: Super Bowl XLIII
#
# Q: where does archbishop desmond tutu live?
# A: South Africa
#
# Q: where do the florida marlins play spring training?
# A: University of Florida
#
# Q: who did annie oakley married?
# A: Frank E. Butler
#
# Q: where does the zambezi river start?
# A: Mwinilunga
#
# Q: where will tebow go in 2013?
# A: New York Jets
#
# Q: where did they find jenni rivera's body?
# A: Iturbide, Nuevo León
#
# Q: where is jason mraz from?
# A: Mechanicsville
#
# Q: what killed john bonham?
# A: Inhalation of vomit
#
# Q: what county is texarkana arkansas in?
# A: Miller County
#
# Q: what team was chris paul on?
# A: Los Angeles Clippers
#
# Q: what country was slovakia?
# A: Czechoslovakia
#
# Q: what is the national flower of hawaii?
# A: Hawaiian hibiscus
#
# Q: where to go fishing in roanoke va?
# A: Rainbow Bluff Expedition
#
# Q: what languages do they speak in costa rica?
# A: Spanish Language
#
# Q: where did hank marvin come from?
# A: Newcastle upon Tyne
#
# Q: when did chipper jones get drafted?
# A: 1990 Major League Baseball Draft
#
# Q: what part did winona ryder play in star trek?
# A: Amanda Grayson
#
# Q: what war did hitler lose?
# A: World War II
#
# Q: where did jovan belcher kill himself?
# A: Kansas City
#
# Q: what time is it in texas houston right now?
# A: Central Time Zone
#
# Q: who is princess leia in star wars?
# A: Carrie Fisher
#
# Q: who played obi wan in episode 2?
# A: Ewan McGregor
#
# Q: where did venus williams come from?
# A: Lynwood
#
# Q: where does the zambezi river originate?
# A: Tanzania
#
# Q: what team did ronaldo play for in 2003?
# A: Real Madrid C.F.
#
# Q: where does robin williams live 2011?
# A: San Francisco
#
# Q: who played jacob black in twilight?
# A: Taylor Lautner
#
# Q: who does lee clark manager?
# A: Birmingham City F.C.
#
# Q: where to get a marriage license in long island?
# A: United States District Court for the Eastern District of New York
#
# Q: what team did adrian peterson play for in college?
# A: University of Oklahoma
#
# Q: where does name pennsylvania come from?
# A: William Penn
#
# Q: what kind of money do they use in germany?
# A: Euro
#
# Q: who plays blaine in batman?
# A: Him/Herself
#
# Q: what did james chadwick invent?
# A: Neutron
#
# Q: what language does australia use?
# A: English Language
#
# Q: what position did vince lombardi play in college?
# A: Right Guard
#
# Q: who plays stephanie plum in one for the money?
# A: Katherine Heigl
#
# Q: what did the ancient romans speak?
# A: Latin Language
#
# Q: where was st. lucy born?
# A: Syracuse
#
# Q: where did salvador dali study art?
# A: Real Academia de Bellas Artes de San Fernando
#
# Q: who was the father of king george vi?
# A: George V
#
# Q: what national team does cristiano ronaldo play for?
# A: Portugal national football team
#
# Q: what flower is on the oklahoma quarter?
# A: Scissor-tailed Flycatcher
#
# Q: where did al qaeda attack?
# A: Iraq War
#
# Q: who was philip in acts chapter 8?
# A: Apostle Philip
#
# Q: what islands did darwin study finches on?
# A: The purpose of the expedition, which lasted for nearly four years, was to survey the east and west coasts of South America, but it also took in the Cape Verde Islands, the Galapagos, Tahiti, New Zealand, Australia, Mauritius and South Africa.
#
# Q: what does egfr african american mean on a blood test?
# A: Protein
#
# Q: what is the best currency to take to turkey?
# A: Turkish lira
#
# Q: what system of government is practiced in nigeria?
# A: Federal republic
#
# Q: what else did alexander graham bell invent other than the telephone?
# A: Graphaphone
#
# Q: where did holly madison get her breast implants?
# A: United States of America
#
# Q: who were mary shelley?
# A: Author
#
# Q: where is denmark situated?
# A: Euroregion Baltic
#
# Q: where was teddy roosevelt's house?
# A: New York City
#
# Q: what type of money do they use in costa rica?
# A: Costa Rican colón
#
# Q: what timezone is nashville tn?
# A: Central Time Zone
#
# Q: what does the sun in the philippine flag represent?
# A: Province of the Philippines
#
# Q: who was anakin skywalker?
# A: Darth Vader
#
# Q: where did adolf hitler die?
# A: Berlin
#
# Q: what is the largest nation in europe?
# A: Russia
#
# Q: who are the senators of virginia 2013?
# A: Mark Warner
#
# Q: where did paula deen go to school?
# A: Albany High School
#
# Q: where does robert irvine come from?
# A: Salisbury
#
# Q: what style of music does michael jackson perform?
# A: Pop music
#
# Q: what does david beckham play?
# A: Midfielder
#
# Q: what is the second biggest state in the united states?
# A: Hawaii
#
# Q: who led the mexican army at the battle of the alamo?
# A: Joaquín Amaro
#
# Q: what school did michael jackson go to high school?
# A: Montclair College Preparatory School
#
# Q: what college did brett favre?
# A: The University of Southern Mississippi
#
# Q: what time does registration open portland state?
# A: Zora Lancaster
#
# Q: where did alex chilton die?
# A: New Orleans
#
# Q: what college did martin luther king jr go to?
# A: Morehouse College
#
# Q: where is harley davidson made?
# A: United States of America
#
# Q: what kind of cancer did farrah fawcett die of?
# A: Anal cancer
#
# Q: who is michael j fox's wife?
# A: Tracy Pollan
#
# Q: what money do i use in costa rica?
# A: Costa Rican colón
#
# Q: what guitar did joe walsh play?
# A: Fender Stratocaster
#
# Q: what are the official languages of the eu?
# A: English Language
#
# Q: what did african americans do during the revolutionary war?
# A: Continental Army Regiment
#
# Q: what language do most italians speak?
# A: Italian Language
#
# Q: what broncos are in the pro bowl?
# A: Peyton Manning
#
# Q: what money do they use in spain?
# A: Euro
#
# Q: when is saint george day celebrated?
# A: April 23
#
# Q: which country won the crimean war?
# A: Russian Empire
#
# Q: who voiced darth vader?
# A: James Earl Jones
#
# Q: where are the texas rangers playing?
# A: Rangers Ballpark in Arlington
#
# Q: what did andrew johnson accomplish as president?
# A: Reconstruction after the Civil War
#
# Q: what is arkansas state capitol?
# A: Little Rock
#
# Q: what is the best tour to egypt?
# A: eg
#
# Q: where to go in vietnam beaches?
# A: Đắk Nông Province
#
# Q: when did michael vick start playing for the eagles?
# A: 2009 NFL season
#
# Q: where do kfc get their chicken from?
# A: Kentucky
#
# Q: what is william taft famous for?
# A: President of the United States
#
# Q: who was jesse james killed by?
# A: The Assassination of Jesse James by the Coward Robert Ford
#
# Q: where did robin cook die?
# A: Inverness
#
# Q: where did melba beals live?
# A: Arkansas
#
# Q: how large is kony army?
# A: Kony 2012: Part II - Beyond Famous
#
# Q: who is louisiana state senator?
# A: Mary Landrieu
#
# Q: where did derek fisher go to college?
# A: University of Arkansas at Little Rock
#
# Q: who was kobe bryant drafted by?
# A: Los Angeles Lakers
#
# Q: where are the new orleans hornets moving to?
# A: New Orleans Arena
#
# Q: where was anne boleyn executed?
# A: Tower of London
#
# Q: what did galileo do to become famous?
# A: Astronomer
#
# Q: what school did martin luther king jr received his doctorate degree from?
# A: Boston University
#
# Q: where buddha come from?
# A: Lumbini
#
# Q: what did king henry viii rule?
# A: England
#
# Q: where is byron nelson 2012?
# A: Roanoke
#
# Q: who is in charge of libya now?
# A: President of the General National Congress of Libya
#
# Q: what currency does australia use 2012?
# A: Australian dollar
#
# Q: when did shays rebellion start?
# A: 1786
#
# Q: what kind of disease does montel williams have?
# A: Multiple sclerosis
#
# Q: where do flemish come from?
# A: Belgium
#
# Q: when is the last time the ravens won a superbowl?
# A: Super Bowl XLVII
#
# Q: where did kansas city royals come from?
# A: Kansas City
#
# Q: what is the theme of scarlet letter by nathaniel hawthorne?
# A: Dark romanticism
#
# Q: where did djokovic come from?
# A: Serbia
#
# Q: who is the arizona cardinals backup quarterback?
# A: John Skelton
#
# Q: what part of the country is new england?
# A: Northeastern United States
#
# Q: what money to take to turkey?
# A: Turkish lira
#
# Q: what kind of music did jimi hendrix play?
# A: Rock music
#
# Q: when tupac was shot?
# A: Tupac 1994 assault
#
# Q: when did liverpool fc last win the champions league?
# A: 2006 FA Cup Final
#
# Q: who played jeannie?
# A: Barbara Eden
#
# Q: what kind of shoes do french people wear?
# A: jansegers
#
# Q: where was st peter killed?
# A: Rome
#
# Q: who does jeremy shockey play for in 2012?
# A: Carolina Panthers
#
# Q: what college did deion sanders jr go to?
# A: Florida State University
#
# Q: when did the battle of alamo start?
# A: 2/23/1836
#
# Q: what was queen elizabeth ii childhood nickname?
# A: Lillibet
#
# Q: where did tim tebow grow up?
# A: Manila
#
# Q: who played victoria barkley?
# A: Barbara Stanwyck
#
# Q: where did kennedy's inaugural address take place?
# A: John F. Kennedy 1961 presidential inauguration
#
# Q: where did the taliban began?
# A: Afghanistan
#
# Q: what kind of government system did ancient egypt have?
# A: Government of Egypt
#
# Q: who plays elena gilbert on vampire diaries?
# A: Nina Dobrev
#
# Q: what happened to jill valentine?
# A: BSAA
#
# Q: what does the missouri river bisect?
# A: Mississippi River
#
# Q: what nationality is taylor lautner jacob black?
# A: United States of America
#
# Q: what animal represents california?
# A: California grizzly bear
#
# Q: what year did ray allen join the nba?
# A: 1996
#
# Q: what is claire danes famous for?
# A: Actor
#
# Q: what county is san antonio in?
# A: Comal County
#
# Q: what characters does matt stone do?
# A: Kyle / Kenny / Jesus
#
# Q: what type of government did soviet union have?
# A: Communist state
#
# Q: what languages are there in japan?
# A: Japanese Language
#
# Q: what year did the bulls get rodman?
# A: 1995–96 NBA season
#
# Q: where did vince scully go to college?
# A: Fordham University
#
# Q: where does princess leia live?
# A: Alderaan
#
# Q: where did mary bell live?
# A: Newcastle upon Tyne
#
# Q: what countries don need a visa for usa?
# A: us
#
# Q: who did kimberly williams marry?
# A: Brad Paisley
#
# Q: what is the currency of germany now?
# A: Euro
#
# Q: what kind of hispanic is selena gomez?
# A: Mexicans
#
# Q: who did denise van outen married?
# A: Lee Mead
#
# Q: what are egyptian money called?
# A: Egyptian pound
#
# Q: who is the president of costa rica in 2012?
# A: Laura Chinchilla
#
# Q: where did martin luther king got shot at?
# A: Memphis
#
# Q: who wrote the gospel according to john?
# A: John the Evangelist
#
# Q: what college football team did john elway play for?
# A: Stanford University
#
# Q: who did nasri play for before arsenal?
# A: Olympique de Marseille
#
# Q: what currency does the czech republic use now?
# A: Czech koruna
#
# Q: what age did william penn get married?
# A: william penn not favored by william of orange
#
# Q: what is the capital of republic of ireland?
# A: Dublin
#
# Q: what did dr josef mengele do?
# A: Physician
#
# Q: what kind of language does egypt speak?
# A: Modern Standard Arabic
#
# Q: what county is st james city fl in?
# A: Lee County
#
# Q: after how many years are the olympic games held?
# A: Once every two years
#
# Q: when was the last time the ny knicks won a playoff game?
# A: 1973 NBA Finals
#
# Q: who is the president of the european union 2012?
# A: Jerzy Buzek
#
# Q: when is st joseph birthday?
# A: March 19
#
# Q: what year was kenya moore crowned miss usa?
# A: Miss USA 1993
#
# Q: what sort of government does nigeria have?
# A: Federal republic
#
# Q: where does chef ina garten live?
# A: Brooklyn
#
# Q: when the atlanta braves won the world series?
# A: 1995 World Series
#
# Q: what is lamar odom doing now july 2012?
# A: Los Angeles Clippers
#
# Q: what was the first language spoken in spain?
# A: Spanish Language
#
# Q: what school did miley cyrus?
# A: Heritage Elementary School
#
# Q: which hemingway book to read?
# A: A Farewell to Arms
#
# Q: what language do most people speak in afghanistan?
# A: Pashto language
#
# Q: who is the prime minister of jamaica west indies?
# A: Portia Simpson-Miller
#
# Q: when did juventus win the champions league?
# A: 1996 UEFA Champions League Final
#
# Q: when does school start for the university of oregon?
# A: University of Oregon
#
# Q: who is robin roberts father?
# A: Lawrence E. Roberts
#
# Q: what is the capital of australia victoria state?
# A: Melbourne
#
# Q: where is french spoken most?
# A: France
#
# Q: what team is reggie bush on 2011?
# A: New Orleans Saints
#
# Q: what highschool did emily osment go to?
# A: Flintridge Preparatory School
#
# Q: what currency should i take to mexico?
# A: Mexican peso
#
# Q: where did troy aikman play football?
# A: Dallas Cowboys
#
# Q: who played cletus hogg?
# A: Jack Polick
#
# Q: who won fa cup 1976?
# A: Manchester United F.C.
#
# Q: what did general robert e lee die from?
# A: Pneumonia
#
# Q: what style of art did henri matisse do?
# A: Impressionism
#
# Q: who plays chuck bass in gossip girl?
# A: Ed Westwick
#
# Q: what county is st. louis park in?
# A: Hennepin County
#
# Q: when does parliament sit in canberra?
# A: Old Parliament House, Canberra
#
# Q: what timezone is tucson arizona in right now?
# A: Mountain Time Zone
#
# Q: when was lucy lawless born?
# A: New Zealand
#
# Q: which political party does barack obama represent?
# A: Democratic Party
#
# Q: where is the empire of ghana?
# A: West Africa
#
# Q: what kind of leukemia did jill clayburgh have?
# A: B-cell chronic lymphocytic leukemia
#
# Q: what is the name of the book hitler wrote in jail?
# A: Mein Kampf
#
# Q: what is there to see in sydney australia?
# A: Sydney Opera House
#
# Q: where was marilyn monroe found dead?
# A: Brentwood
#
# Q: what language is spoken in greek?
# A: Greek Language
#
# Q: what team did monta ellis get traded to?
# A: Milwaukee Bucks
#
# Q: what is the name of the speaker of the house of representatives now 2011?
# A: Nancy Pelosi
#
# Q: who plays stanley hudson?
# A: Leslie David Baker
#
# Q: where does tim roth come from?
# A: England
#
# Q: what kind of equipment did isaac newton use?
# A: Reflecting telescope
#
# Q: what currency should you take to vietnam?
# A: Vietnamese dong
#
# Q: who did roger federer married?
# A: Mirka Federer
#
# Q: what kind of money do i need in costa rica?
# A: Costa Rican colón
#
# Q: what caused the embargo against cuba?
# A: Fulgencio Batista
#
# Q: what is the name of the capital of belgium?
# A: City of Brussels
#
# Q: who was selena gomez in barney and friends?
# A: Gianna
#
# Q: where did the gettysburg address?
# A: Gettysburg
#
# Q: what kind of tennis racquet does serena williams use?
# A: Yetunde Price
#
# Q: who was president in 1988 in the united states?
# A: Ronald Reagan
#
# Q: where can you find wind turbines in canada?
# A: Alberta
#
# Q: what drink did john pemberton create?
# A: Coca-Cola
#
# Q: what type of government does brazil have 2011?
# A: Brazilian Labour Renewal Party
#
# Q: what was bonnie prince charlie full name?
# A: Charles Edward Stuart
#
# Q: who makes the voice of stewie griffin?
# A: Seth MacFarlane
#
# Q: who is the governor of indiana 2009?
# A: Mitch Daniels
#
# Q: what party does barack obama belong to?
# A: Democratic Party
#
# Q: what do people in france like to do for fun?
# A: Cycling
#
# Q: where did john mayer go to college?
# A: Berklee College of Music
#
# Q: what is malaysian currency?
# A: Malaysian ringgit
#
# Q: who owns volkswagen car company?
# A: Volkswagen Group
#
# Q: which is the main train station in rome?
# A: Roma Termini railway station
#
# Q: what did steve mcnair died from?
# A: Ballistic trauma
#
# Q: who is the newly elected governor of california?
# A: Jerry Brown
#
# Q: who plays roxanne in ghost rider?
# A: Daryl Hannah
#
# Q: where is the sony ericsson company?
# A: London
#
# Q: what kind of currency does the dominican republic have?
# A: Dominican peso
#
# Q: where is the main headquarters of google?
# A: California
#
# Q: what was jesse owens education?
# A: Ohio State University
#
# Q: where does carlos santana live?
# A: Jalisco
#
# Q: what was goebbels role?
# A: "After Hitler's coup in 1933, Goebbels was named "Reich Minister for Public Enlightenment and Propaganda" and president of the newly-formed "Chamber of Culture", which gave him total control over Germany's media."
#
# Q: what county is houston tx in?
# A: Montgomery County
#
# Q: where do the seattle seahawks play?
# A: CenturyLink Field
#
# Q: who does michael keaton play in cars?
# A: Chick Hicks
#
# Q: what are the mountains in northern spain?
# A: Pyrenees
#
# Q: where is the riviera casino?
# A: Las Vegas
#
# Q: who became president when henry harrison died?
# A: John Tyler
#
# Q: where did richard arkwright grow up?
# A: England
#
# Q: when did roth ira originate?
# A: William V. Roth, Jr.
#
# Q: what is the best zelda game to start with?
# A: The Legend of Zelda: Ocarina of Time
#
# Q: who does the voice for darth vader?
# A: James Earl Jones
#
# Q: what is the dominant religion in the us?
# A: Christianity
#
# Q: what is the zip code for newark california?
# A: 94560
#
# Q: what states share a border with tennessee?
# A: Virginia
#
# Q: what war did the us lose the most soldiers?
# A: Vietnam War
#
# Q: what did obama do before he was elected president?
# A: Illinois State Senator
#
# Q: where do john lennon die?
# A: New York City
#
# Q: who plays edward on deception?
# A: Robert Pattinson
#
# Q: what was herbert hoover best known for?
# A: President of the United States
#
# Q: what is the current time in bangalore india?
# A: UTC+05:30
#
# Q: where is the phillies spring training stadium?
# A: Philadelphia
#
# Q: where is harley davidson corporate headquarters?
# A: Milwaukee
#
# Q: when was john paul ii?
# A: 10/16/1978
#
# Q: where is belgium germany?
# A: Western Europe
#
# Q: where did starbucks get their logo?
# A: Howard Schultz
#
# Q: where was bin laden found and killed?
# A: Abbottabad
#
# Q: what did dr jack kevorkian do?
# A: Assisted suicide
#
# Q: what does bolivia border?
# A: Brazil
#
# Q: who plays stacey in the stacy's mom video?
# A: Lacey Turner
#
# Q: what is the currency of sweden in 2010?
# A: Swedish krona
#
# Q: what country does justin bieber come from?
# A: Canada
#
# Q: what is the head judge of the supreme court called?
# A: Chief Justice of the United States
#
# Q: who was frida kahlo influenced by?
# A: Diego Rivera
#
# Q: where is taylor swift from?
# A: Reading
#
# Q: when is the last time the giants won the world series?
# A: 2012 World Series
#
# Q: what is the main language used in china?
# A: Chinese language
#
# Q: where did the battle of waterloo occur?
# A: Waterloo
#
# Q: what spain brought to the new world?
# A: Spanish Language
#
# Q: who did vladimir lenin marry?
# A: Nadezhda Krupskaya
#
# Q: what year did the baltimore ravens win superbowl?
# A: 2000 NFL season
#
# Q: what team does cristiano ronaldo play for 2011?
# A: Real Madrid C.F.
#
# Q: what is money called in italy?
# A: Euro
#
# Q: what is the government of france for 2010?
# A: Constitutional republic
#
# Q: where did theodor schwann study?
# A: Humboldt University of Berlin
#
# Q: how old is bruno mars and where is he from?
# A: Honolulu
#
# Q: who are the virginia senators 2013?
# A: Mark Warner
#
# Q: what was dr seuss's real name?
# A: Theodor Robert Geisel
#
# Q: what countries are members of the security council?
# A: Verdict on Kashmir
#
# Q: where are the nordic countries?
# A: Northern Europe
#
# Q: what country sponsored ferdinand magellan?
# A: Portugal
#
# Q: what did vera ellen die from?
# A: Cancer
#
# Q: what is the capital of modern day egypt?
# A: Cairo
#
# Q: what province is toronto in ( 7 letters )?
# A: Ontario
#
# Q: where do most illegal immigrants in the us come from?
# A: Mexico
#
# Q: who will plaxico burress play for in 2011?
# A: New York Jets
#
# Q: what is the currency of brazil now?
# A: Brazilian real
#
# Q: what types of art did andy warhol do?
# A: Pop art
#
# Q: who does mike marry at the end of season 5 desperate housewives?
# A: Susan Delfino
#
# Q: who will coach carolina panthers in 2013?
# A: Ron Rivera
#
# Q: where did louis sachar grow up?
# A: East Meadow
#
# Q: who plays marshall eriksen?
# A: Jason Segel
#
# Q: what activities are there to do in greece?
# A: Ionian Islands
#
# Q: where did otto frank go to college?
# A: Heidelberg College
#
# Q: who is the governor of pennsylvania state now?
# A: Tom Corbett
#
# Q: where is ancient phoenician?
# A: Lebanon
#
# Q: where does the celtics practice?
# A: TD Bank Garden
#
# Q: what did george washington do as a teenager?
# A: Surveyor
#
# Q: where bin laden got killed?
# A: Abbottabad
#
# Q: where does toronto get its water from?
# A: Ashbridges Bay Wastewater Treatment Plant
#
# Q: what is the name of sonia gandhi daughter?
# A: Priyanka Vadra
#
# Q: who do islamic people pray to?
# A: Allah
#
# Q: where did charles darwin die?
# A: Down House
#
# Q: when did the big earthquake hit san francisco?
# A: 1906 San Francisco earthquake
#
# Q: who was king george vi married to?
# A: Queen Elizabeth The Queen Mother
#
# Q: where was jesus after he died on the cross?
# A: Church of the Holy Sepulchre
#
# Q: who voiced darth vader in the original star wars movies?
# A: James Earl Jones
#
# Q: what high school did maya angelou go to?
# A: George Washington High School
#
# Q: what country did benito mussolini govern?
# A: Italy
#
# Q: where did mubarak get his wealth?
# A: Politician
#
# Q: who was the leader of the first communist party of china?
# A: Chen Duxiu
#
# Q: when did the detroit pistons last win the championship?
# A: 2004 NBA Finals
#
# Q: who is number 22 for the dallas cowboys?
# A: Felix Jones
#
# Q: what county is st paul nc in?
# A: Robeson County
#
# Q: where did nat turner 1831 rebellion occur?
# A: Virginia
#
# Q: who would play luke skywalker?
# A: Mark Hamill
#
# Q: who won the presidential election in egypt 2012?
# A: Hosni Mubarak
#
# Q: what state is barack obama from?
# A: Hawaii
#
# Q: what years did joe montana win super bowl?
# A: Super Bowl XIX
#
# Q: what percent of americans have college degree?
# A: Why Race Mattered in Barack Obama's Re-election
#
# Q: what caused the cuban rebellion in 1868?
# A: Ten Years' War
#
# Q: where did alexander graham bell die?
# A: Beinn Bhreagh, Nova Scotia
#
# Q: what year did the golden state warriors win their first nba championship?
# A: 1975 NBA Finals
#
# Q: what currency should i take to turkey?
# A: Turkish lira
#
# Q: what type of government did mexico have?
# A: Federal republic
#
# Q: who played lauren reed on alias?
# A: Melissa George
#
# Q: who is the king of cambodia now?
# A: Norodom Sihamoni
#
# Q: what was the cause of death for huell howser?
# A: Prostate cancer
#
# Q: what countries does england border?
# A: Scotland
#
# Q: what team did messi play for in 2010?
# A: Argentina national football team
#
# Q: what time zone is greensburg indiana?
# A: North American Eastern Time Zone
#
# Q: what fma stands for?
# A: FullMetal Alchemist
#
# Q: what is the university of georgia known for?
# A: Georgia Bulldogs basketball
#
# Q: what jobs did john adams have before he was president?
# A: Vice President of the United States
#
# Q: what year did super mario bros 2 come out?
# A: Zilog Z80
#
# Q: where did joseph's family live?
# A: Canaan
#
# Q: where was osama bin laden killed?
# A: Abbottabad
#
# Q: where were greek temples built?
# A: Europe
#
# Q: who was queen elizabeth ii mom?
# A: Queen Elizabeth The Queen Mother
#
# Q: who did ricky martin started his career with?
# A: Menudo
#
# Q: who does don draper gets engaged to?
# A: Betty Draper
#
# Q: what was van halen first album?
# A: Van Halen
#
# Q: what led to the split of the republican party in 1912?
# A: Zachariah Chandler
#
# Q: what is penn state's main campus?
# A: University Park
#
# Q: when is the rainy season in bangkok thailand?
# A: September
#
# Q: where did the israel palestine conflict start?
# A: 1936–39 Arab revolt in Palestine
#
# Q: what country does alaska belong to?
# A: United States of America
#
# Q: where is kansas city?
# A: Platte County
#
# Q: what was pink floyd's first album?
# A: The Piper at the Gates of Dawn
#
# Q: who did granville t. woods married?
# A: Loretta Woods
#
# Q: what type of government did thomas jefferson prefer?
# A: Unitarianism
#
# Q: who did brett gardner play for in 2008?
# A: New York Yankees
#
# Q: who plays dwight in the office?
# A: Rainn Wilson
#
# Q: who plays riley on buffy the vampire slayer?
# A: Marc Blucas
#
# Q: what county is san diego ca?
# A: San Diego County
#
# Q: who is the miami dolphins quarterback?
# A: Pat Devlin
#
# Q: where did the yoruba originated from?
# A: African people
#
# Q: where did anne frank go to school?
# A: Montessori Lyceum Amsterdam
#
# Q: what basketball player is married to monica?
# A: Shannon Brown
#
# Q: when is the last time the denver broncos won the superbowl?
# A: Super Bowl XXXIII
#
# Q: where was caesar when he was stabbed?
# A: Theatre of Pompey
#
# Q: what time zone is chicago in right now?
# A: Central Time Zone
#
# Q: what two countries make up the dominican republic?
# A: Hispaniola
#
# Q: who was the vice president under ronald reagan?
# A: George H. W. Bush
#
# Q: where do the chicago white sox play home games?
# A: U.S. Cellular Field
#
# Q: what part did jeff conaway play in grease?
# A: Kenickie Murdoch
#
# Q: what currency to take to barbados?
# A: Barbadian dollar
#
# Q: where did they get the name stanley cup?
# A: Frederick Stanley, 16th Earl of Derby
#
# Q: what is the space needle in toronto?
# A: CN Tower
#
# Q: who was queen victoria's husband?
# A: Albert, Prince Consort
#
# Q: what does barbara bush do for work?
# A: First Lady
#
# Q: what happened to dunkirk during ww2?
# A: Battle of Dunkirk
#
# Q: what was scottie pippen good at?
# A: Basketball
#
# Q: who played donna on west wing?
# A: Catherine Tate
#
# Q: who played meg in season 1 of family guy?
# A: Lacey Chabert
#
# Q: when was the last time the dallas cowboys won the superbowl?
# A: Super Bowl XXX
#
# Q: what did napoleon bonaparte do as emperor?
# A: After graduating from military school in 1785, Napoleon became a Second-Lieutenant of Artillery in the regiment of La Fere, garrisoned at Valence, in southern France where he studied military tactics and strategy and the philosophical works of Voltaire and Rousseau.
#
# Q: where do ireland play rugby union?
# A: Zarathustra
#
# Q: who killed lee harvey oswald shot?
# A: Jack Ruby
#
# Q: when was the last time knicks won the championship?
# A: 1973 NBA Finals
#
# Q: what country is nicki minaj from?
# A: Trinidad and Tobago
#
# Q: who played harry potter dumbledore actor?
# A: Dane Farwell
#
# Q: who was the prime minister of pakistan in 1999?
# A: Nawaz Sharif
#
# Q: what is capital city of morocco?
# A: Rabat
#
# Q: what did bruce jenner win gold medal for?
# A: Decathlon challenge
#
# Q: where do they speak tibetan?
# A: Tibet
#
# Q: who ran against abraham lincoln for president in 1860?
# A: Stephen A. Douglas
#
# Q: where did kim kardashian come from?
# A: Los Angeles
#
# Q: what town did justin bieber grew up in?
# A: London
#
# Q: what is michael kors best known for?
# A: Fashion Designer
#
# Q: who plays charlie in the santa clause movies?
# A: Kansas City Athletics
#
# Q: where does the expression excuse my french come from?
# A: English Literature
#
# Q: what highschool did r. kelly attend?
# A: Kenwood Academy
#
# Q: what country is nike based in?
# A: United States of America
#
# Q: what is the percentage of youth in uganda?
# A: Uganda
#
# Q: what kind of money do i bring to mexico?
# A: Mexican peso
#
# Q: who did steve spurrier play pro football for?
# A: San Francisco 49ers
#
# Q: what is the only colony on the south america continent?
# A: French Guiana
#
# Q: where do the blackhawks play?
# A: United Center
#
# Q: what is the main language spoken in mexico?
# A: Spanish Language
#
# Q: who played captain kirk in star trek movie?
# A: William Shatner
#
# Q: who played dana scully in x files?
# A: Gillian Anderson
#
# Q: who was the first governor of colonial south carolina?
# A: Thomas Pinckney
#
# Q: what is the dominant language spoken in jamaica?
# A: Jamaican English
#
# Q: who is the coach for the new york knicks?
# A: Mike Woodson
#
# Q: where does sherrod brown live?
# A: Mansfield
#
# Q: what currency does england use now?
# A: UK £
#
# Q: who was the original voice of meg griffin on family guy?
# A: Lacey Chabert
#
# Q: who did cristiano ronaldo play for in 2010?
# A: Real Madrid C.F.
#
# Q: what is jacksonville fl timezone?
# A: North American Eastern Time Zone
#
# Q: who does amy stiller play in dodgeball?
# A: Keno Waitress
#
# Q: who does mila kunis play on family guy?
# A: Meg Griffin
#
# Q: when did the san francisco earthquake occur?
# A: 1906 San Francisco earthquake
#
# Q: what athlete am i olympics?
# A: The complete book of the Winter Olympics
#
# Q: what concentration camp did anne frank died in?
# A: Bergen-Belsen concentration camp
#
# Q: when did gordon brown resigns?
# A: 7 January, 2007
#
# Q: what is the currency in italy?
# A: Euro
#
# Q: where does greek language come from?
# A: Indo-European languages
#
# Q: what is the name of the currency used in italy?
# A: Euro
#
# Q: where is audrey hepburn from?
# A: Ixelles
#
# Q: where did the australian floods take place?
# A: Queensland
#
# Q: who does darth vaders voice?
# A: James Earl Jones
#
# Q: when is nrl grand final day?
# A: NRL Grand Final
#
# Q: what school did douglas macarthur go to?
# A: TMI — The Episcopal School of Texas
#
# Q: what is the name of the currency used in china?
# A: Renminbi
#
# Q: what currency to take to turkey 2010?
# A: Turkish lira
#
# Q: who is the current governor of arizona 2010?
# A: Jan Brewer
#
# Q: when was the most recent earthquake in haiti?
# A: 2010 Haiti Earthquake
#
# Q: who is lamar odom playing for this year?
# A: Los Angeles Clippers
#
# Q: where were the great pyramids of giza built?
# A: Giza Plateau
#
# Q: what country was king tut's tomb found?
# A: Ancient Egypt
#
# Q: where did abraham and his descendants live?
# A: Canaan
#
# Q: where president obama was born?
# A: Honolulu
#
# Q: who was demi lovato dating?
# A: Joe Jonas
#
# Q: where did tony gonzalez play college basketball?
# A: University of California, Berkeley
#
# Q: who originally voiced meg on family guy?
# A: Mila Kunis
#
# Q: who played amy squirrel in bad teacher?
# A: Lucy Punch
#
# Q: who did viggo mortensen play in lord of the rings?
# A: Aragorn
#
# Q: what lands did henry hudson discover?
# A: Hudson Bay
#
# Q: who did william shakespeare marry?
# A: Anne Hathaway
#
# Q: what country does david luiz play for?
# A: Brazil
#
# Q: where is victoria british columbia?
# A: Canada
#
# Q: what do we call the currency of france?
# A: French franc
#
# Q: what team does david beckham play for in 2012?
# A: LA Galaxy
#
# Q: what radio station is npr on in nyc?
# A: WNYC
#
# Q: where was john jay born?
# A: New York City
#
# Q: where is mount fuji located?
# A: Honshu
#
# Q: when is venus brightest?
# A: Western astrology
#
# Q: where was toussaint l'ouverture born?
# A: Haiti
#
# Q: what is the capital city of spain wiki answers?
# A: Madrid
#
# Q: when did mark mcgwire retired?
# A: 2001 Major League Baseball season
#
# Q: what is colorado technical university?
# A: Career Education Corporation
#
# Q: what is kentucky state slogan?
# A: United we stand, divided we fall
#
# Q: what did elvis presley died from?
# A: Myocardial infarction
#
# Q: who played samantha stephens in bewitched?
# A: Elizabeth Montgomery
#
# Q: what county is san diego in?
# A: San Diego County
#
# Q: which country in north america is divided into provinces?
# A: Canada
#
# Q: where is the scottish house in skyfall?
# A: Celts
#
# Q: when does daylight saving end in new zealand 2012?
# A: nz
#
# Q: what is real name of santa claus?
# A: Saint Nicholas
#
# Q: when did kelly slater go pro?
# A: 2008 ASP World Tour
#
# Q: what did coretta scott king died from?
# A: Respiratory failure
#
# Q: what does wh smith stand for?
# A: William Henry Smith
#
# Q: what type of drugs did whitney houston?
# A: Cocaine overdose
#
# Q: where is the illinois river on a map?
# A: Illinois
#
# Q: where honduras in the world?
# A: Central America
#
# Q: who do pagans worship?
# A: Odin
#
# ...
#
# Q: who are the members of the supreme court 2009?
# A: John Roberts
#
# Q: who does the voice for chucky in child's play?
# A: Brad Dourif
#
# Q: what did mary wollstonecraft fight for?
# A: Women's rights
#
# Q: what is new france?
# A: North America
#
# Q: what year did the phillies begin?
# A: 1883
#
# Q: what country is dyson made?
# A: United Kingdom
#
# Q: what language does iceland speak?
# A: Icelandic Language
#
# Q: what was dr seuss real name?
# A: Theodor Robert Geisel
#
# Q: where to eat crawfish in beaumont?
# A: Uzooma Okeke
#
# Q: what language they speak in scotland?
# A: Scottish English
#
# Q: what boarding school did mark zuckerberg go to?
# A: Phillips Exeter Academy
#
# Q: what are bigos?
# A: Stew
#
# Q: when did shaq come into the nba?
# A: 1992 NBA Draft
#
# Q: what is the zip code for walnut creek?
# A: 94597
#
# Q: who will the cavaliers draft 2012?
# A: Dion Waiters
#
# Q: who was the voice of darth vader in the original star wars movie?
# A: James Earl Jones
#
# Q: what music did louis armstrong play?
# A: Jazz
#
# Q: what form of currency does germany use?
# A: Euro
#
# Q: what did andy irons die from?
# A: Myocardial infarction
#
# Q: where did leif ericson grow up?
# A: Iceland
#
# Q: what language do the maasai speak?
# A: Maasai Language
#
# Q: who is the leader of north korea today?
# A: Kim Jong-un
#
# Q: where do the appalachian mountains run through?
# A: Eastern United States
#
# Q: what money does spain use?
# A: Euro
#
# Q: where was terry waite born?
# A: Bollington
#
# Q: what country did the battle of san juan hill take place?
# A: Cuba
#
# Q: what kind of government does the united states have currently?
# A: Federal republic
#
# Q: when was the last time the orioles won the world series?
# A: 1983 World Series
#
# Q: what did shakespeare learn in grammar school?
# A: william shakespeare performed play by thomas dekker
#
# Q: who did ben stiller date?
# A: Christine Taylor
#
# Q: what is the most common language in norway?
# A: Norwegian Language
#
# Q: where did benjamin franklin went to school?
# A: Boston Latin School
#
# Q: who is the governor of arizona 2009?
# A: Jan Brewer
#
# Q: what did bernie mac died of?
# A: Pneumonia
#
# Q: what countries does the arctic circle run through?
# A: North Greenland
#
# Q: where is electrolux based?
# A: Stockholm
#
# Q: what is houston timezone?
# A: Central Time Zone
#
# Q: where do italy people live?
# A: Italy
#
# Q: what was shakespeare's wife called?
# A: Anne Hathaway
#
# Q: when did truman become president?
# A: 4/12/1945
#
# Q: when was abraham lincoln declared president?
# A: Abraham Lincoln 1861 presidential inauguration
#
# Q: where do burmese cats originate from?
# A: Asia
#
# Q: what county is st paul minnesota in?
# A: Ramsey County
#
# Q: who does david beckham play for?
# A: Paris Saint-Germain F.C.
#
# Q: who won the battle of gettysburg?
# A: United States of America
#
# Q: where was franz ferdinand from?
# A: Glasgow
#
# Q: what was benedict arnold most famous for?
# A: Traitor
#
# Q: who plays lex luthor on smallville?
# A: Michael Rosenbaum
#
# Q: what does bentley mean?
# A: Bentley Motors Limited
#
# Q: what is the currency of the czech republic?
# A: Czech koruna
#
# Q: when was the last time the la kings won a playoff series?
# A: 2012 Stanley Cup Finals
#
# Q: where did spencer pratt go to school?
# A: University of Southern California
#
# Q: who is vancouver canucks coach?
# A: Alain Vigneault
#
# Q: where did cs lewis wrote?
# A: Belfast
#
# Q: what is carlos pena jr nationality?
# A: Dominican Republic
#
# Q: who was married to jane wyman?
# A: Bing Crosby & Jane Wyman
#
# Q: who played mickey in the rocky movies?
# A: Wayne Allwine
#
# Q: what timezone is phoenix az in right now?
# A: Mountain Time Zone
#
# Q: what was the name of henry viii first wife?
# A: Catherine of Aragon
#
# Q: what is president nixon's first name?
# A: Richard
#
# Q: where did theodor schwann get his education?
# A: Humboldt University of Berlin
#
# Q: what year did houston rockets win their first championship?
# A: 1994 NBA Finals
#
# Q: where do most of the people live in russia?
# A: Moscow
#
# Q: who plays nicholas newman on the young and the restless?
# A: Joshua Morrow
#
# Q: who is the voice of eric cartman on south park?
# A: Trey Parker
#
# Q: who is angelina jolies brother?
# A: James Haven
#
# Q: where is the headquarters of bank of america?
# A: Charlotte
#
# Q: who was king after leonidas died?
# A: Pleistarchus
#
# Q: when was the leafs last in the playoffs?
# A: 1967 Stanley Cup Finals
#
# Q: where is burundi country?
# A: Africa
#
# Q: when does the world end according to the mayans time?
# A: 2012
#
# Q: what did werner heisenberg discover?
# A: Matrix mechanics
#
# Q: what city does paul ryan live in?
# A: Janesville
#
# Q: what is the national language of iran?
# A: Persian Language
#
# Q: where did the second battle of ypres occur?
# A: Belgium
#
# Q: what languages do people speak in spain?
# A: Spanish Language
#
# Q: what did michael crabtree do?
# A: Wide receiver
#
# Q: who plays ziva david on ncis?
# A: Cote de Pablo
#
# Q: who ruled after king henry viii died?
# A: Edward VI of England
#
# Q: where is daud ibrahim?
# A: Maharashtra
#
# Q: what language do russians speak?
# A: Russian Language
#
# Q: where was martin luther king jr buried?
# A: Martin Luther King, Jr., National Historic Site
#
# Q: what country does rafael nadal play for?
# A: Spain
#
# Q: who is the prime minister of spain 2011?
# A: Mariano Rajoy
#
# Q: who was the son of king leonidas?
# A: Pleistarchus
#
# Q: who was judi dench married to?
# A: Michael Williams
#
# Q: where are the sahara desert located?
# A: North Africa
#
# Q: what is rihanna mum called?
# A: Monica Braithwaite
#
# Q: what county is san francisco?
# A: San Francisco
#
# Q: when did president theodore roosevelt take office?
# A: 9/14/1901
#
# Q: who does michael oher play for in 2010?
# A: Baltimore Ravens
#
# Q: where does egypt export to?
# A: Sudan
#
# Q: who did messi have a baby with?
# A: Antonella Roccuzzo
#
# Q: where is the seat of the african union?
# A: Addis Ababa
#
# Q: what ship did darwin sail around the world?
# A: HMS Beagle
#
# Q: where did christopher columbus began his journey?
# A: Portugal
#
# Q: what artistic style did henri rousseau work in?
# A: Post-Impressionism
#
# Q: what is john edwards indicted for?
# A: Political corruption
#
# Q: where was huey newton killed?
# A: Oakland
#
# Q: when was the printing press invented by gutenberg?
# A: This suggests that by 1438 Gutenberg and Dritzehen had in all probability already invented a printing process using moveable type (separate pieces of wood or metal for each letter of the alphabet).
#
# Q: where does marta play soccer?
# A: Umeå IK
#
# Q: where is mitt romney's family from?
# A: Detroit
#
# Q: what city was michael jackson born in?
# A: Gary
#
# Q: which city is the oldest in pakistan?
# A: Bahawalpur
#
# Q: what kind of writing is nikolai gogol famous for?
# A: Dramatist
#
# Q: what year was first world series?
# A: 1903 World Series
#
# Q: who plays simon birch?
# A: Ian Michael Smith
#
# Q: where are the timezones in the usa?
# A: Pacific Time Zone
#
# Q: what does gm make?
# A: Automobile
#
# Q: what was wayne gretzky's first team?
# A: Edmonton Oilers
#
# Q: who is the president of peru now?
# A: Ollanta Humala
#
# Q: who are the senators of new jersey now?
# A: Bob Menendez
#
# Q: what team does messi play for 2011?
# A: FC Barcelona
#
# Q: where does lil wayne go to school?
# A: University of Houston
#
# Q: what airport is nearest to rome?
# A: Ciampino – G.B. Pastine International Airport
#
# Q: what state is saint louis university in?
# A: Missouri
#
# Q: what factors led to the rise of the roman empire?
# A: Ulpian
#
# Q: what type of currency do they use in spain?
# A: Euro
#
# Q: what did lincoln steffens wrote?
# A: The shame of the cities
#
# Q: what schools did anders celsius attend?
# A: Uppsala University
#
# Q: what can do in new york?
# A: Central Park
#
# Q: what language do they speak in colombia south america?
# A: Spanish Language
#
# Q: when was the last tsunami in the atlantic ocean?
# A: Île Saint-Joseph
#
# Q: what did george washington carver made?
# A: Peanut butter
#
# Q: what's my timezone in oklahoma?
# A: Central Time Zone
#
# Q: what does ss stand for in hitler's army?
# A: Schutzstaffel
#
# Q: what currency does singapore use?
# A: Singapore dollar
#
# Q: who plays robin hood in prince of thieves?
# A: Kevin Costner
#
# Q: what standard time is texas?
# A: Central Time Zone
#
# Q: where does kurdish people live?
# A: Asia
#
# Q: what instrument does louis armstrong?
# A: Trumpeter
#
# Q: who does alyson stoner play in camp rock?
# A: Caitlyn Gellar
#
# Q: when was michael jordan at his best?
# A: 1995–96 NBA season
#
# Q: what made richard hammond famous?
# A: Top Gear
#
# Q: who originally voiced lois griffin?
# A: Alex Borstein
#
# Q: who plays sheldon cooper mother on the big bang theory?
# A: Jim Parsons
#
# Q: what rihanna new album called 2012?
# A: Unapologetic
#
# Q: where does dave ramsey live?
# A: Nashville
#
# Q: what does a dream deferred by langston hughes?
# A: Dreams and Youth
#
# Q: what was the japanese war called?
# A: World War II
#
# Q: what did nikola tesla invented that is of use today?
# A: Tesla coil
#
# Q: who plays the role of tony dinozzo on ncis?
# A: Michael Weatherly
#
# Q: what is the state name of new york city?
# A: New York
#
# Q: where is the main branch of bank of america?
# A: Charlotte
#
# Q: who plays knox overstreet?
# A: Josh Charles
#
# Q: where did sally pearson go to primary school?
# A: Helensvale State High School
#
# Q: what is the stanley cup named after?
# A: Frederick Stanley, 16th Earl of Derby
#
# Q: what language did the ancient babylonians speak?
# A: Akkadian language
#
# Q: what was franklin d roosevelt's job before president?
# A: Governor of New York
#
# Q: where did robert downey jr go to jail?
# A: California Substance Abuse Treatment Facility and State Prison, Corcoran
#
# Q: what does god shiva represent?
# A: Hinduism
#
# Q: what is the name of the currency used in switzerland?
# A: Swiss franc
#
# Q: what year did the milwaukee brewers go to the world series?
# A: 1974 Major League Baseball Season
#
# Q: who was vice president with bill clinton?
# A: Al Gore
#
# Q: what year did the la kings win the cup?
# A: 2012 Stanley Cup Finals
#
# Q: what kind of money does egypt have?
# A: Egyptian pound
#
# Q: what baseball team was jackie robinson on?
# A: Brooklyn Dodgers
#
# Q: what body of water does st lawrence river flow into?
# A: Gulf of Saint Lawrence
#
# Q: who was william mckinley married to?
# A: Ida Saxton McKinley
#
# Q: who played darth vader in the first movie?
# A: David Prowse
#
# Q: where did kevin james go to college?
# A: SUNY College at Cortland
#
# Q: what year was hitler was born?
# A: Adolf Hitler was born in 1889 at Braunau am Inn, Austria, the son of a 52- year-old Habsburg customs official, Alois Schickelgruber Hitler, and his third wife, a young peasant girl named Klara Poelzl.
#
# Q: what did canada get gold medals in?
# A: Diving at the 1984 Summer Olympics - Women's 3 metre springboard
#
# Q: where was auschwitz concentration camp located?
# A: Poland
#
# Q: what kind of currency does dominican republic use?
# A: Dominican peso
#
# Q: where was shakespeare born at?
# A: Stratford-upon-Avon
#
# Q: where did scott fitzgerald go to college?
# A: Princeton University
#
# Q: what year was allen iverson mvp?
# A: 2000–01 NBA season
#
# Q: what county is utica ny in?
# A: Oneida County
#
# Q: what did charles babbage discover?
# A: The Difference Engine: Charles Babbage and the Quest to Build the First Computer
#
# Q: what are members of the house of representatives called?
# A: Representative
#
# Q: who plays king julian madagascar?
# A: Sacha Baron Cohen
#
# Q: what century did slavery end in america?
# A: Western Hemisphere
#
# Q: who did james franco play in milk?
# A: Him/Herself
#
# Q: when did the libyan conflict start?
# A: 2011
#
# Q: what city did marco polo came from?
# A: Venice
#
# Q: what wnba team is diana taurasi on?
# A: Phoenix Mercury
#
# Q: what is newcastle metro?
# A: Tyne and Wear
#
# Q: what other organisms did mendel use in experiments?
# A: Experiments in plant hybridisation
#
# Q: what year did adam morrison get drafted?
# A: 2006 NBA Draft
#
# Q: where michael jackson from?
# A: Gary
#
# Q: what college did maya moore go to?
# A: University of Connecticut
#
# Q: when was the last time the dodgers won a championship?
# A: 1988 World Series
#
# Q: who is captain james cook facts?
# A: Explorer
#
# Q: where did robin williams get married?
# A: St. Helena
#
# Q: who do islamic people follow?
# A: Allah
#
# Q: what kind of government does peru?
# A: Presidential system
#
# Q: who founded the afl?
# A: Bud Adams
#
# Q: where did diego velazquez die?
# A: Madrid
#
# Q: what did warren buffett invest in?
# A: Berkshire Hathaway
#
# Q: what is the country code for mexico?
# A: mx
#
# Q: what currency do they use in switzerland?
# A: Swiss franc
#
# Q: what does british colony mean?
# A: British American
#
# Q: when olympic games 2012 opening ceremony?
# A: The Olympic Odyssey
#
# Q: where is president kennedy buried?
# A: Arlington National Cemetery
#
# Q: who won the michigan ohio state game 2012?
# A: Ohio State Buckeyes football
#
# Q: where was the prophet mohammed from?
# A: Mecca
#
# Q: which country in europe has the largest land area?
# A: Russia
#
# Q: when did kaley cuoco join charmed?
# A: Charmed Season 8
#
# Q: where is chris rock from?
# A: Andrews
#
# Q: when was the last time the toronto maple leafs win the stanley cup?
# A: 1967 Stanley Cup Finals
#
# Q: what kind of language do egyptian speak?
# A: Modern Standard Arabic
#
# Q: what position did vince lombardi play?
# A: Right Guard
#
# Q: who played stanley kowalski in a streetcar named desire movie?
# A: Marlon Brando
#
# Q: what book did charles darwin wrote in 1859?
# A: The Origin of Species
#
# Q: what language do serbs speak?
# A: Serbian language
#
# Q: what was the cause of death for laci peterson?
# A: Murder
#
# Q: what team is kris humphries play for?
# A: Brooklyn Nets
#
# Q: what was the government like in virginia colony?
# A: Government of Virginia
#
# Q: where did john franklin live?
# A: Blue Island
#
# Q: what language do bosnian muslims speak?
# A: Bosnian language
#
# Q: what was tycho brahe theory?
# A: Brahe's astronomical investigations began to suggest that the existing literature on the solar system was inaccurate.
#
# Q: what was the last movie sean connery was in?
# A: Sir Billi
#
# Q: what team did drogba play for?
# A: Galatasaray S.K.
#
# Q: where did crabtree go to college?
# A: Texas Tech University
#
# Q: where does freddie ljungberg come from?
# A: Sweden
#
# Q: who is number 22 on miami dolphins?
# A: Reshad Jones
#
# Q: where is staten island ferry?
# A: Staten Island
#
# Q: what state did john adams live in?
# A: Massachusetts
#
# Q: what type of music did vivaldi compose?
# A: Baroque music
#
# Q: what college did john nash teach at?
# A: Princeton University
#
# Q: what team does mike fisher play for?
# A: Nashville Predators
#
# Q: what materials did eduardo paolozzi use in his work?
# A: Sculpture
#
# Q: who did marilyn monroe marry at 16?
# A: James Dougherty
#
# Q: who plays timon's voice in the lion king?
# A: Nathan Lane
#
# Q: what part of the country is ohio in?
# A: Midwestern United States
#
# Q: which island is kailua on?
# A: Hawaii
#
# Q: what did whoopi goldberg won a grammy for?
# A: Grammy Award for Best Comedy Album
#
# Q: what is modern day judah?
# A: Jerusalem
#
# Q: who played maggie in himym?
# A: Nancy Cartwright
#
# Q: who does owen schmitt play for?
# A: Seattle Seahawks
#
# Q: what party was thomas jefferson affiliated with?
# A: Democratic-Republican Party
#
# Q: what religions are popular in france?
# A: Catholicism
#
# Q: who played berger in sex and the city?
# A: for amos
#
# Q: who won the 2000 fa cup final?
# A: Liverpool F.C.
#
# Q: what are the names of michael jackson's kids?
# A: Paris-Michael Katherine Jackson
#
# Q: who plays bob kelso in scrubs?
# A: Ken Jenkins
#
# Q: what do people in czech republic speak?
# A: Croatian language
#
# Q: where does tim cook work?
# A: Apple Inc.
#
# Q: where is bob marley buried?
# A: Bob Marley Mausoleum
#
# Q: what is london uk time zone?
# A: Greenwich Mean Time
#
# Q: where to stay in chicago tourist?
# A: Hotel Sax Chicago
#
# Q: what type of breast cancer did sheryl crow have?
# A: Meningioma
#
# Q: where does fabio capello come from?
# A: Italy
#
# Q: who did morgan freeman marry?
# A: Myrna Colley-Lee
#
# Q: what are the mountains in northern italy called?
# A: Alps
#
# Q: in which state was the battle of antietam fought?
# A: 9/17/1862
#
# Q: which ocean does the zambezi river flow into?
# A: Indian Ocean
#
# Q: what team did david beckham play for before la galaxy?
# A: Preston North End F.C.
#
# Q: who is the current leader of france 2010?
# A: Nicolas Sarkozy
#
# Q: where is roswell area 51?
# A: Roswell
#
# Q: when was father chris riley born?
# A: 1967

# %%
import random 
def format_example(example):
    question = example["question"]
    # Pick the first gold answer (you can change this logic if needed)
    answer = example["answers"][0]
    return f"Q: {question}\nA: {answer}"

# Create few-shot examples
def get_few_shot_examples(dataset, k=5, seed=42):
    random.seed(seed)
    indices = random.sample(range(len(dataset)), k)
    return "\n\n".join(format_example(dataset[i]) for i in indices)

# Example: get 5-shot prompt
few_shot_prompt = get_few_shot_examples(train_ds, k=5)
print(few_shot_prompt)
# Out:
# Q: who is the governor of hawaii now?
# A: Neil Abercrombie
#
# Q: what was nelson mandela's religion?
# A: Methodism
#
# Q: who played sean in scrubs?
# A: Michael Jackson: 30th Anniversary Special
#
# Q: what political party was henry clay?
# A: Whig Party
#
# Q: who are iran's major trading partners?
# A: Madagascar

# %%
import transformers
transformers.__version__
# Out:
# '4.49.0'

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

from constants import MODEL_PATHs

model_name = "qwen3_1.7b"

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-1.7B")
# model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-1.7B")

tokenizer = AutoTokenizer.from_pretrained(MODEL_PATHs[model_name])
model = AutoModelForCausalLM.from_pretrained(MODEL_PATHs[model_name])
tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1092, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1091 try:
# -> 1092     config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1093 except KeyError:
#
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:794, in _LazyConfigMapping.__getitem__(self, key)
#     793 if key not in self._mapping:
# --> 794     raise KeyError(key)
#     795 value = self._mapping[key]
#
# KeyError: 'qwen3'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 14
#      10 # tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-1.7B")
#      11 # model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-1.7B")
#      13 tokenizer = AutoTokenizer.from_pretrained(MODEL_PATHs[model_name])
# ---> 14 model = AutoModelForCausalLM.from_pretrained(MODEL_PATHs[model_name])
#      15 tokenizer.pad_token_id = tokenizer.eos_token_id
#
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:526, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     523 if kwargs.get("quantization_config", None) is not None:
#     524     _ = kwargs.pop("quantization_config")
# --> 526 config, kwargs = AutoConfig.from_pretrained(
#     527     pretrained_model_name_or_path,
#     528     return_unused_kwargs=True,
#     529     trust_remote_code=trust_remote_code,
#     530     code_revision=code_revision,
#     531     _commit_hash=commit_hash,
#     532     **hub_kwargs,
#     533     **kwargs,
#     534 )
#     536 # if torch_dtype=auto was passed here, ensure to pass it on
#     537 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1094, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1092         config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1093     except KeyError:
# -> 1094         raise ValueError(
#    1095             f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#    1096             "but Transformers does not recognize this architecture. This could be because of an "
#    1097             "issue with the checkpoint, or because your version of Transformers is out of date.\n\n"
#    1098             "You can update Transformers with the command `pip install --upgrade transformers`. If this "
#    1099             "does not work, and the checkpoint is very new, then there may not be a release version "
#    1100             "that supports this model yet. In this case, you can get the most up-to-date code by installing "
#    1101             "Transformers from source with the command "
#    1102             "`pip install git+https://github.com/huggingface/transformers.git`"
#    1103         )
#    1104     return config_class.from_dict(config_dict, **unused_kwargs)
#    1105 else:
#    1106     # Fallback: use pattern matching on the string.
#    1107     # We go from longer names to shorter names to catch roberta before bert (for instance)
#
# ValueError: The checkpoint you are trying to load has model type `qwen3` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.
#
# You can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`

# %%
qa_instruction = "Answer the question based on general world knowledge. Provide a short and direct answer."
def generate_answers(prompts):
    model.generation_config.temperature=None
    model.generation_config.top_p=None

    prompts = [f"{qa_instruction}\n\n{few_shot_prompt}\n\nQ: {prompt}\nA:" for prompt in prompts]
    input_ids = tokenizer(
        prompts, 
        padding=True, truncation=True,
        padding_side='left',        
        return_tensors="pt",
        return_attention_mask=True).input_ids.to(model.device)
    generated_ids = model.generate(
        input_ids, 
        max_new_tokens=20, 
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id)

    generated_texts = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    new_generated_texts = [gen[len(prompt):].strip() for gen, prompt in zip(generated_texts, prompts)]
    return prompts, new_generated_texts

# %%
from torch.utils.data import DataLoader

def webqa_collate_fn(batch):
    questions = [item["question"] for item in batch]
    answers = [item["answers"] for item in batch]  # answers is a list of lists
    return questions, answers

# %%
import re
import string

def normalize_answer(s):
    """Lower text and remove punctuation, articles, and extra whitespace."""
    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        return ''.join(ch for ch in text if ch not in string.punctuation)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def exact_match_score(predictions,  ):
    """Return 1 if the prediction matches any gold answer after normalization."""
    pred_norms = [normalize_answer(pred) for pred in predictions]
    answer_norms = [normalize_answer(answer) for answer in gold_answers]
    return sum([1 if pred == ans else 0 for pred, ans in zip(pred_norms, answer_norms)])/len(predictions)

# %%
from tqdm import tqdm
all_preds1 = []
all_prompts1 = []
all_answers1 = []

dataloader = DataLoader(test_ds, batch_size=8, webqa_collate_fn=webqa_collate_fn)
for questions, answers in tqdm(dataloader):
    answers = [ans[0] for ans in answers]
    prompts, generations = generate_answers(questions)
    predictions = [gen.strip().split('\n')[0] for gen in generations]
    all_preds1.extend(predictions)
    all_answers1.extend(answers)
    all_prompts1.extend(prompts)

# %%
exact_match = exact_match_score(all_preds1, all_answers1)
exact_match

# %%
def get_few_shot_paraphrases(few_shot=False, idx=0):
    instruction = """
Paraphrase the following question. Keep the original meaning, but use a different sentence structure and vocabulary. Aim to make the paraphrase sound natural and diverse.
    """

    example_prompts = [
        "who is the governor of hawaii now?",
        "what was nelson mandela's religion?",
        "who played sean in scrubs?",
        "what political party was henry clay?",
        "who are iran's major trading partners?"
    ]

    paraphrased_prompts = [
        [
            "as of now, who leads Hawaii as its governor?",
            "who's currently serving as Hawaii's governor?",
            "can you tell me who governs Hawaii right now?",
            "who’s in charge of the Hawaii state government these days?",
            "who’s the top executive official in Hawaii right now?"
        ],
        [
            "what was Mandela’s faith tradition",
            "can you tell me Mandela’s religion?",
            "what faith did Nelson Mandela practice?",
            "what was the religious affiliation of Nelson Mandela?",
            "what religion did Nelson Mandela follow?"
        ],
        [
            "which actor portrayed Sean in Scrubs?",
            "who took on the role of Sean in Scrubs?",
            "who played the character Sean in the TV show Scrubs?",
            "who was the actor that played Sean in the series Scrubs?",
            "do you know who played the part of Sean in Scrubs?"
        ],
        [
            "Henry Clay was a member of which political party?",
            "to which party did Henry Clay pledge his allegiance?",
            "what political affiliation did Henry Clay have?",
            "under which political banner did Henry Clay serve?",
            "where did Henry Clay stand on the political party map?"
        ],
        [
            "who does Iran trade with the most?",
            "who are the primary countries doing business with Iran?",
            "what are Iran’s strongest trade relationships?",
            "which countries top the list of Iran’s key trade allies?",
            "which countries are central to Iran’s import and export network?"
        ]
    ]

    few_shot_prompt = [f"Q: {prompt}\nParaphrase: {para}" for prompt, para in zip(example_prompts, [paras[idx] for paras in paraphrased_prompts])]
    if few_shot:
        prompts = f"{instruction}\n" + "\n\n".join(few_shot_prompt)
    else:
        prompts = f"{instruction}\n\n"
    return prompts

# %%
print(get_few_shot_paraphrases(few_shot=True))

# %%
import torch
import random
import numpy as np


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def generate_paraphrases(prompts, idx, seed=42):
    context = get_few_shot_paraphrases(few_shot=True, idx=idx)
    # print(context)
    prompts = [f"{context}\n\nQ: {prompt}\nParaphrase:" for prompt in prompts]
    input_ids = tokenizer(
        prompts, 
        padding=True, truncation=True,
        padding_side='left',        
        return_tensors="pt",
        return_attention_mask=True).input_ids.to(model.device)

    set_seed(seed)
    generated_ids = model.generate(
        input_ids, 
        max_new_tokens=30, 
        do_sample=True,
        temperature=1.5,
        top_p=0.9,
        pad_token_id=tokenizer.eos_token_id)

    generated_texts = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    new_generated_texts = [gen[len(prompt):].strip() for gen, prompt in zip(generated_texts, prompts)]
    return new_generated_texts

# %%
all_preds2 = []
all_answers2 = []
all_prompts2 = []
paras = []
for i in range(5):
    print(f"Generating paraphrases for iteration {i+1}")
    all_paraphrases = []
    for questions, answers in tqdm(dataloader):
        answers = [ans[0] for ans in answers]
        generations = generate_paraphrases(questions, idx=i, seed=i)
        paraphrases = [gen.strip().split('\n')[0] for gen in generations]
        all_paraphrases.extend(paraphrases)
        # break
    paras.append(all_paraphrases)

# %%
for all_paras in paras:
    print(all_paras[10])

# %%
# prompts, generations2 = generate_answers(paraphrases)
# predictions = [gen.strip().split('\n')[0] for gen in generations2]
# all_preds2.extend(predictions)
# all_answers2.extend(answers)
# all_prompts2.extend(prompts)

# exact_match2 = exact_match_score(all_preds2, all_answers2)
# exact_match2

# %%
questions[0], paraphrases[0]

# %%
def get_ensemble_fewshot():
    example_prompts = [
        "who is the governor of hawaii now?",
        "what was nelson mandela's religion?",
        "who played sean in scrubs?",
        "what political party was henry clay?",
        "who are iran's major trading partners?"
    ]

    paraphrased_prompts = [
        "as of now, who leads Hawaii as its governor?",
        "what was Mandela’s faith tradition",
        "which actor portrayed Sean in Scrubs?",
        "Henry Clay was a member of which political party?",
        "who does Iran trade with the most?"
    ]

    answers = ["Neil Abercrombie", "Methodism", "Michael Jackson: 30th Anniversary Special", "Whig Party", "Madagascar"]

    few_shot_prompt = [f"Q: {prompt} In other word, {para}\nA: {ans}" for prompt, para, ans in zip(example_prompts, paraphrased_prompts, answers)]
    prompts = f"{qa_instruction}\n\n" + "\n\n".join(few_shot_prompt)
    return prompts
print(get_ensemble_fewshot())

# %%
test_ds2 = dataloader.dataset.add_column("paraphrase1", paras[0])
test_ds2 = test_ds2.add_column("paraphrase2", paras[1])
test_ds2 = test_ds2.add_column("paraphrase3", paras[2])
test_ds2 = test_ds2.add_column("paraphrase4", paras[3])
test_ds2 = test_ds2.add_column("paraphrase5", paras[4])

# %%
def webqa_collate_fn2(batch):
    questions = [item["question"] for item in batch]
    answers = [item["answers"] for item in batch]
    paraphrases = [item["paraphrases"] for item in batch]
    return questions, answers, paraphrases

dataloader2 = DataLoader(test_ds2, batch_size=8, webqa_collate_fn=webqa_collate_fn2)

# %%
all_preds3 = []
all_prompts3 = []
all_answers3 = []

def generate_answers_ensemble(prompts, paraphrases):
    model.generation_config.temperature=None
    model.generation_config.top_p=None
    
    context = get_ensemble_fewshot()
    prompts = [f"{context}\n\nQ: {prompt} In other words, {para}\nA:" for prompt, para in zip(questions, paraphrases)]
    all_prompts3.extend(prompts)
    
    input_ids = tokenizer(
        prompts, 
        padding=True, truncation=True,
        padding_side='left',        
        return_tensors="pt",
        return_attention_mask=True).input_ids.to(model.device)
    generated_ids = model.generate(
        input_ids, 
        max_new_tokens=20, 
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id)

    generated_texts = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    new_generated_texts = [gen[len(prompt):].strip() for gen, prompt in zip(generated_texts, prompts)]
    return new_generated_texts

for questions, answers, paraphrases in tqdm(dataloader2):
    model.generation_config.temperature=None
    model.generation_config.top_p=None

    answers = [ans[0] for ans in answers]
    generated_answers = generate_answers_ensemble(questions, paraphrases)

    predictions = [gen.strip().split('\n')[0] for gen in generated_answers]
    all_preds3.extend(predictions)
    all_answers3.extend(answers)

exact_match3 = exact_match_score(all_preds3, all_answers3)
exact_match3

# %%
pred_norms1 = [normalize_answer(pred) for pred in all_preds1]
answer_norms1 = [normalize_answer(answer) for answer in all_answers1]
matched1 = [1 if pred in answer_norms1 else 0 for pred in pred_norms1]

pred_norms2 = [normalize_answer(pred) for pred in all_preds2]
answer_norms2 = [normalize_answer(answer) for answer in all_answers2]
matched2 = [1 if pred in answer_norms2 else 0 for pred in pred_norms2]  

pred_norms3 = [normalize_answer(pred) for pred in all_preds3]
answer_norms3 = [normalize_answer(answer) for answer in all_answers3]
matched3 = [1 if pred in answer_norms3 else 0 for pred in pred_norms3]

# %%
e12, e23, e13 = 0, 0, 0
e123 = 0
for m1, m2, m3 in zip(matched1, matched2, matched3):
    if m1 == m2:
        e12 += 1
    if m2 == m3:
        e23 += 1
    if m1 == m3:
        e13 += 1
    if m1 == m2 == m3:
        e123 += 1

print(e12/len(matched1), e23/len(matched2), e13/len(matched3), e123/len(matched1))

# %%
test_ds2 = test_ds2.add_column("prompts1", all_prompts1)
test_ds2 = test_ds2.add_column("prompts2", all_prompts2)
test_ds2 = test_ds2.add_column("prompts3", all_prompts3)

# %%
test_ds2.save_to_disk("./webqa_test_fewshot_ensemble_llama3.2_3b_it_paraphrase")

# %%
from datasets import load_from_disk
ds = load_from_disk("webqa_test_fewshot_ensemble")
