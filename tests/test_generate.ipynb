# %%
import os
import pandas as pd
    "root = \"/net/tokyo100-10g/data/str01_01/y-guo/datasets/myriadlama/llama3.1_8b_it/\"\n",
df = pd.read_feather(os.path.join(root, "ensemble_avg-2.feather"))

# %%
df["answer_lemmas"] = df["answer_lemmas"].apply(lambda xs: [list(x) for x in xs])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'answer_lemmas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df["answer_lemmas"] = df["answer_lemmas"].apply(lambda xs: [list(x) for x in xs])
#
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/softwares/anaconda3/envs/eval/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'answer_lemmas'

# %%
df
# Out:
#                                 uuid  \
# 0    5d09424876ba7f4-15e8746c51e1d4c
# 1    fd915def246a0be-1df91599c979dd7
# 2    846cc35c6fe6013-279430e3ef1ffac
# 3    2be6c939e56239c-5db887161a9ced7
# 4    703b74b9c96d4e5-fd2c6d248ec9c51
# ..                               ...
# 995  3c925a742aa2513-f1e377a90f5b247
# 996  cf6ce13163e7293-d1d8d9a4ae58d7e
# 997  7bdd7145e01a7e2-ea38347e369f45f
# 998  099aebbcc1f2017-7c27241618d5873
# 999  109ca04420be7bd-98e34e15e6607cd
#
#                                                answers        prediction  \
# 0                 [NBC, National Broadcasting Company]               BBC
# 1    [physics, physical, physic, general physics, p...       mathematics
# 2                  [Norwegian, no, Norwegian language]            Danish
# 3    [Florence, Firenze, Florence, Italy, Florence,...          Florence
# 4                    [Antarctica, Antarctic Selection]        Antarctica
# ..                                                 ...               ...
# 995  [Saint Petersburg, St. Petersburg, Petrograd, ...            Jaffna
# 996  [Apple, Apple Computer, Inc., Apple Computer I...             Apple
# 997  [Anatolia, Asian Turkey, Anatolian Peninsula, ...  Byzantine Empire
# 998          [Luton, Luton, Bedfordshire, Luton Urban]            London
# 999               [English, English language, en, eng]           English
#
#                                             generation  \
# 0    BBC\n\nQ: [MASK] is a type of tree.\nA: oak\n\...
# 1    mathematics\n\nQ: [MASK] is a type of tree.\nA...
# 2    Danish\n\nQ: [MASK] is a type of tree.\nA: oak...
# 3    Florence\n\nQ: [MASK] is a type of tree.\nA: o...
# 4    Antarctica\n\nQ: [MASK] is a type of tree.\nA:...
# ..                                                 ...
# 995  Jaffna\n\nQ: [MASK] is a type of tree.\nA: oak...
# 996  Apple\n\nQ: [MASK] is a type of tree.\nA: oak\...
# 997  Byzantine Empire\n\nQ: [MASK] is a type of tre...
# 998  London\n\nQ: [MASK] is a type of tree.\nA: oak...
# 999  English\n\nQ: [MASK] is a type of tree.\nA: oa...
#
#                                            paraphrases  \
# 0    [This Is Your Life premiered on the network [M...
# 1    [Johann Heinrich Lambert has work experience i...
# 2    [In which language is Vinduet written? [MASK]....
# 3    [Where did Francesco Pesellino die? [MASK]., F...
# 4    [Queen Maud Land is a part of the continent [M...
# ..                                                 ...
# 995  [Colombo and [MASK] are twin cities., Which ci...
# 996  [Audio Interchange File Format was originally ...
# 997  [Battle of Hyelion and Leimocheir is located i...
# 998  [Hemel Hempstead and [MASK] are neighboring co...
# 999  [[MASK] is the language that is used by Muhamm...
#
#                                                prompts        predict_lemma  \
# 0    [Predict the [MASK] in the sentence in one wor...                [bbc]
# 1    [Predict the [MASK] in the sentence in one wor...         [mathematic]
# 2    [Predict the [MASK] in the sentence in one wor...             [danish]
# 3    [Predict the [MASK] in the sentence in one wor...           [florence]
# 4    [Predict the [MASK] in the sentence in one wor...         [antarctica]
# ..                                                 ...                  ...
# 995  [Predict the [MASK] in the sentence in one wor...             [jaffna]
# 996  [Predict the [MASK] in the sentence in one wor...              [apple]
# 997  [Predict the [MASK] in the sentence in one wor...  [byzantine, empire]
# 998  [Predict the [MASK] in the sentence in one wor...             [london]
# 999  [Predict the [MASK] in the sentence in one wor...            [english]
#
#                                          answer_lemmas
# 0           [[nbc], [national, broadcasting, company]]
# 1    [[physics], [physical], [physic], [general, ph...
# 2           [[norwegian], [no], [norwegian, language]]
# 3    [[florence], [firenze], [florence, ,, italy], ...
# 4               [[antarctica], [antarctic, selection]]
# ..                                                 ...
# 995  [[saint, petersburg], [st., petersburg], [petr...
# 996  [[apple], [apple, computer, ,, inc.], [apple, ...
# 997  [[anatolia], [asian, turkey], [anatolian, peni...
# 998  [[luton], [luton, ,, bedfordshire], [luton, ur...
# 999      [[english], [english, language], [en], [eng]]
#
# [1000 rows x 8 columns]

# %%
df[df['uuid']==list(df['uuid'].unique())[1]]
# Out:
#                               uuid  \
# 1  fd915def246a0be-1df91599c979dd7
#
#                                              answers   prediction  \
# 1  [physics, physical, physic, general physics, p...  mathematics
#
#                                           generation  \
# 1  mathematics\n\nQ: [MASK] is a type of [MASK].\...
#
#                                          paraphrases  \
# 1  [Johann Heinrich Lambert has work experience i...
#
#                                              prompts predict_lemma  \
# 1  [Predict the [MASK] in the sentence in one wor...  [mathematic]
#
#                                        answer_lemmas
# 1  [[physics], [physical], [physic], [general, ph...
